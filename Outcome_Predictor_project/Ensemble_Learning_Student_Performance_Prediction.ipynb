# %% [markdown]
# ## **Part B: Dataset Understanding & Preparation**

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier,AdaBoostRegressor

# %%
data = pd.read_csv('students_dataset.csv')

# %%
data.columns
# Out:
# Index(['student_id', 'age', 'country_region', 'device_type',
#        'education_background', 'course_level', 'course_category',
#        'course_start_date', 'week_of_year', 'sessions', 'time_spent_hours',
#        'videos_watched', 'quiz_attempts', 'assignments_submitted',
#        'forum_posts', 'avg_quiz_score', 'attendance_rate', 'completion_status',
#        'final_score'],
#       dtype='object')

# %% [markdown]
# ### Task 6: Feature & Target Identification

# %%
X = data.drop(columns=['student_id','age','device_type','course_start_date'])

# %%
y_cls = data.completion_status

# %%
y_reg = data.final_score

# %% [markdown]
# ### Tasl 8: Data Preprocessing

# %%
# data before preprocessing
X.head()
# Out:
#   country_region education_background  course_level course_category  \
# 0         Europe            Undergrad  Intermediate        Business
# 1         Europe            Undergrad  Intermediate     Programming
# 2         Europe             Graduate      Advanced     Programming
# 3           Asia            Undergrad      Beginner          Design
# 4           Asia           WorkingPro      Advanced        Business
#
#    week_of_year  sessions  time_spent_hours  videos_watched  quiz_attempts  \
# 0            12         1               7.6               1              6
# 1            34        16              27.2               6              4
# 2            39         6               7.1              16              2
# 3            10        34              22.1              57              9
# 4            12        22              32.3              41              9
#
#    assignments_submitted  forum_posts  avg_quiz_score  attendance_rate  \
# ...

# %%
# Cheacking missing values
X.isna().sum()
# Out:
# country_region             0
# education_background       0
# course_level               0
# course_category            0
# week_of_year               0
# sessions                   0
# time_spent_hours         112
# videos_watched             0
# quiz_attempts              0
# assignments_submitted      0
# forum_posts                0
# avg_quiz_score            81
# attendance_rate           80
# completion_status          0
# final_score                0
# dtype: int64

# %%
# Filling missing values with 0
X.fillna(0,inplace=True)

# %%
# Cheacking Datatypes
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5200 entries, 0 to 5199
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   country_region         5200 non-null   object
#  1   education_background   5200 non-null   object
#  2   course_level           5200 non-null   object
#  3   course_category        5200 non-null   object
#  4   week_of_year           5200 non-null   int64
#  5   sessions               5200 non-null   int64
#  6   time_spent_hours       5200 non-null   float64
#  7   videos_watched         5200 non-null   int64
#  8   quiz_attempts          5200 non-null   int64
#  9   assignments_submitted  5200 non-null   int64
#  10  forum_posts            5200 non-null   int64
#  11  avg_quiz_score         5200 non-null   float64
#  12  attendance_rate        5200 non-null   float64
#  13  completion_status      5200 non-null   int64
# ...

# %%
# Making variables for Encoder with and without order
# Categorical values for dropdowns

education = ['HighSchool', 'Undergrad', 'Graduate', 'WorkingPro']

course_lvl = ['Beginner', 'Intermediate', 'Advanced']

country = sorted(X['country_region'].dropna().unique())

course_cat = sorted(X['course_category'].dropna().unique())

print(country)
print(course_cat)
# Out:
# [np.float64(0.0), np.float64(1.0), np.float64(2.0), np.float64(3.0), np.float64(4.0)]
# [np.float64(0.0), np.float64(1.0), np.float64(2.0), np.float64(3.0), np.float64(4.0)]

# %%
# Using Ordinal Encoder for Encoding Categorical features
OE = OrdinalEncoder(
    categories=[education,course_lvl,country,course_cat]
)

# %%
# Replacing values to categorical to numeric
X[['education_background','course_level','country_region','course_category']] = OE.fit_transform(X[['education_background','course_level','country_region','course_category']])

# %%
# Data Overview after Preprocessing
X.head()
# Out:
#    country_region  education_background  course_level  course_category  \
# 0             0.0                   1.0           1.0              0.0
# 1             0.0                   1.0           1.0              1.0
# 2             0.0                   2.0           2.0              1.0
# 3             1.0                   1.0           0.0              2.0
# 4             1.0                   3.0           2.0              0.0
#
#    week_of_year  sessions  time_spent_hours  videos_watched  quiz_attempts  \
# 0            12         1               7.6               1              6
# 1            34        16              27.2               6              4
# 2            39         6               7.1              16              2
# 3            10        34              22.1              57              9
# 4            12        22              32.3              41              9
#
#    assignments_submitted  forum_posts  avg_quiz_score  attendance_rate  \
# ...

# %% [markdown]
# ### Task 7: Train-Test Split

# %%
# Train-Test-Split for Regression 
X_train_reg,X_test_reg,y_train_reg,y_test_reg = train_test_split(X,y_reg,test_size=0.2,random_state=42)

# %%
# Train-Test-Split for Classification 
X_train_cls,X_test_cls,y_train_cls,y_test_cls = train_test_split(X,y_cls,test_size=0.2,random_state=42)

# %% [markdown]
# ## **Part C: Bagging (Bootstrap Aggregation)**

# %%
from sklearn.ensemble import BaggingClassifier,BaggingRegressor
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor

# %% [markdown]
# ### Task: 9: Train a Bagging Classifier

# %%
bag_cls = BaggingClassifier(random_state=42)

# %%
# model training
bag_cls.fit(X_train_cls,y_train_cls)
# Out:
# BaggingClassifier(random_state=42)

# %% [markdown]
# ### Task 10: Train a Bagging Regressor

# %%
bag_reg = BaggingRegressor(random_state=42)

# %%
# model training
bag_reg.fit(X_train_reg,y_train_reg)
# Out:
# BaggingRegressor(random_state=42)

# %% [markdown]
# ### Task 11: Compare bagging results with a single base model

# %%
tree_reg = DecisionTreeRegressor(max_depth=5, min_samples_split=2, random_state=42)
tree_cls = DecisionTreeClassifier(max_depth=5, min_samples_split=2, random_state=42)
tree_reg.fit(X_train_reg,y_train_reg)
# Out:
# DecisionTreeRegressor(max_depth=5, random_state=42)

# %%
# training classification model
tree_cls.fit(X_train_cls,y_train_cls)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
bag_pred_reg = bag_reg.predict(X_test_reg)
tree_pred_reg = tree_reg.predict(X_test_reg)

# %%
bag_pred_cls = bag_cls.predict(X_test_cls)
tree_pred_cls = tree_cls.predict(X_test_cls)

# %%
from sklearn.metrics import accuracy_score,r2_score

# %%
pd.DataFrame({
    'R2 Score': [r2_score(y_test_reg,tree_pred_reg),r2_score(y_test_reg,bag_pred_reg)],
    'Accuracy Score': [r2_score(y_test_cls,tree_pred_cls),r2_score(y_test_cls,bag_pred_cls)]
},index=['Decision Tree','Bagging Model'])
# Out:
#                R2 Score  Accuracy Score
# Decision Tree  0.998326             1.0
# Bagging Model  0.999979             1.0

# %% [markdown]
# **Observation:**
#
# Bagging classifier achieved the same accuracy (1.0) as the base model, indicating no significant improvement. However, bagging regressor showed a slight improvement over the base model.
#
# **Conclusion:**
#
# This suggests that the base model already performs very well, and bagging mainly helped in reducing variance for regression but had minimal impact on classification.

# %% [markdown]
# ## **Part D: Boosting Algorithms**

# %% [markdown]
# ### **AdaBoost**

# %% [markdown]
# #### Task 12: Implement AdaBoost Classifier

# %%
ada_cls = AdaBoostClassifier(n_estimators=100,learning_rate=0.2,random_state=42)

# %%
ada_cls.fit(X_train_cls,y_train_cls)
# Out:
# AdaBoostClassifier(learning_rate=0.2, n_estimators=100, random_state=42)

# %%
ada_pred_cls = ada_cls.predict(X_test_cls)

# %% [markdown]
# #### Task 13: Implement AdaBoost Regressor

# %%
ada_reg = AdaBoostRegressor(n_estimators=100,learning_rate=0.2,random_state=42)

# %%
ada_reg.fit(X_train_reg,y_train_reg)
# Out:
# AdaBoostRegressor(learning_rate=0.2, n_estimators=100, random_state=42)

# %%
ada_pred_reg = ada_reg.predict(X_test_reg)

# %% [markdown]
# #### Task 14: Analyze how weak learners improve sequentially

# %% [markdown]
# AdaBoost improves model performance by training weak learners sequentially, where each new model focuses more on the samples that were misclassified by previous models. It assigns higher weights to incorrectly predicted instances, forcing the next learner to pay more attention to difficult cases.
#
# As the sequence progresses, the model gradually reduces errors by combining all weak learners into a strong final model using weighted voting. This step-by-step correction helps in reducing bias and improving overall accuracy.

# %% [markdown]
# ### **Gradient Boosting**

# %%
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier

# %% [markdown]
# #### Task 15: Implement Gradient Boosting Classifier

# %%
gbm_cls = GradientBoostingClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=3,
    random_state=42)

# %%
gbm_cls.fit(X_train_cls,y_train_cls)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
gbm_pred_cls = gbm_cls.predict(X_test_cls)

# %% [markdown]
# #### Task 16: Implement Gradient Boosting Regresso

# %%
gbm_reg = GradientBoostingRegressor(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=3,
    random_state=42)

# %%
gbm_reg.fit(X_train_reg,y_train_reg)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
gbm_pred_reg = gbm_reg.predict(X_test_reg)

# %% [markdown]
# #### Task 17:Analyze learning rate and number of estimators

# %% [markdown]
# The learning rate controls how much each new model contributes to the final prediction. A smaller learning rate makes the model learn slowly but improves generalization, while a larger learning rate speeds up learning but may cause overfitting.
#
# The number of estimators represents the number of boosting stages (trees). More estimators generally improve performance, but too many can lead to overfitting and increased computation time.
#
# There is a trade-off between learning rate and number of estimators: a low learning rate usually requires more estimators, while a high learning rate requires fewer estimators.

# %% [markdown]
# ### **Light Gradient Boosting (LightGBM)**

# %%
from lightgbm import LGBMClassifier, LGBMRegressor

# %% [markdown]
# #### Task 18: Implement LightGBM Classifier

# %%
lgbm_cls = LGBMClassifier(n_estimators=100,learning_rate=0.05,random_state=42)

# %%
lgbm_cls.fit(X_train_cls,y_train_cls)
# Out:
# [LightGBM] [Info] Number of positive: 1559, number of negative: 2601
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000312 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1270
# [LightGBM] [Info] Number of data points in the train set: 4160, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.374760 -> initscore=-0.511851
# [LightGBM] [Info] Start training from score -0.511851
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
lgbm_pred_cls = lgbm_cls.predict(X_test_cls)

# %% [markdown]
# #### Task 19: Implement LightGBM Regressor

# %%
lgbm_reg = LGBMRegressor(n_estimators=200,learning_rate=0.05,random_state=42)

# %%
lgbm_reg.fit(X_train_reg,y_train_reg)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000263 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1270
# [LightGBM] [Info] Number of data points in the train set: 4160, number of used features: 15
# [LightGBM] [Info] Start training from score 74.774183
# LGBMRegressor(learning_rate=0.05, n_estimators=200, random_state=42)

# %%
lgbm_pred_reg = lgbm_reg.predict(X_test_reg)

# %% [markdown]
# #### Task 20: Analyze performance and training efficiency

# %% [markdown]
# LightGBM provides high performance with faster training compared to traditional boosting methods. It uses a histogram-based approach and leaf-wise tree growth, which reduces computation time and improves accuracy.
#
# In this project, LightGBM achieved strong predictive performance while training significantly faster than other boosting models. It efficiently handled large feature sets and reduced overfitting through techniques like regularization.
#
# Overall, LightGBM offers a good balance between speed and accuracy, making it suitable for large-scale machine learning tasks.

# %% [markdown]
# ### **XGBoost**

# %%
from xgboost import XGBClassifier, XGBRegressor

# %% [markdown]
# #### Task 21: Implement XGBoost Classifier

# %%
xgb_cls = XGBClassifier(
    n_estimators=200,
    learning_rate=0.05,
    max_depth=5,
    random_state=42,
    eval_metric='logloss'
)

# %%
xgb_cls.fit(X_train_cls,y_train_cls)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
xgb_pred_cls = xgb_cls.predict(X_test_cls)

# %% [markdown]
# #### Task 22: Implement XGBoost Regressor

# %%
xgb_reg = XGBRegressor(
    n_estimators=200,
    learning_rate=0.05,
    max_depth=5,
    random_state=42
)

# %%
xgb_reg.fit(X_train_reg,y_train_reg)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=200,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
xgb_pred_reg = xgb_reg.predict(X_test_reg)

# %% [markdown]
# #### Task 23: Compare performance and robustness with other boosting models

# %% [markdown]
# XGBoost demonstrates superior performance and robustness compared to other boosting algorithms like AdaBoost, Gradient Boosting, and LightGBM. It incorporates regularization techniques (L1 and L2), which help prevent overfitting and improve model generalization.
#
# Compared to AdaBoost, XGBoost is more robust as it handles noise and outliers better. Compared to traditional Gradient Boosting, it is faster and more efficient due to parallel processing and optimized tree construction. While LightGBM is faster in training, XGBoost often provides more stable and consistent results across different datasets.
#
# Overall, XGBoost achieves a strong balance between accuracy, speed, and robustness, making it one of the most reliable boosting algorithms for machine learning tasks.

# %% [markdown]
# ## **Part E: Voting and Stacking Ensembles**

# %%
from sklearn.ensemble import VotingClassifier, StackingClassifier,StackingRegressor
from sklearn.neighbors import KNeighborsClassifier,KNeighborsRegressor
from sklearn.svm import SVC,SVR

# %% [markdown]
# ### Task 24: Implement Voting Classifier and Regressor

# %%
# Base models for Voting / Stacking Classifier
dt_cls = DecisionTreeClassifier(random_state=42)
knn_cls = KNeighborsClassifier(n_neighbors=5)
svm_cls = SVC(probability=True,random_state=42)

# %%
# Voting Classifier model - Hard Voting
vote_cls_hard = VotingClassifier(
    estimators=[('dt',dt_cls),('knn',knn_cls),('svm',svm_cls)],
    voting='hard'
)

# %%
vote_cls_hard.fit(X_train_cls,y_train_cls)
# Out:
# VotingClassifier(estimators=[('dt', DecisionTreeClassifier(random_state=42)),
#                              ('knn', KNeighborsClassifier()),
#                              ('svm', SVC(probability=True, random_state=42))])

# %%
# Voting Classifier model - soft Voting
vote_cls_soft = VotingClassifier(
    estimators=[('dt',dt_cls),('knn',knn_cls),('svm',svm_cls)],
    voting='soft'
)

# %%
vote_cls_soft.fit(X_train_cls,y_train_cls)
# Out:
# VotingClassifier(estimators=[('dt', DecisionTreeClassifier(random_state=42)),
#                              ('knn', KNeighborsClassifier()),
#                              ('svm', SVC(probability=True, random_state=42))],
#                  voting='soft')

# %%
vote_pred_cls = vote_cls_soft.predict(X_test_cls)

# %% [markdown]
# ### Task 25: Compare Hard Voting vs Soft Voting

# %% [markdown]
# Hard Voting combines predictions from multiple classifiers by selecting the class with the majority vote. Each model contributes equally, and the final output is based on the most frequent predicted class.
#
# Soft Voting, on the other hand, uses the predicted probabilities of each class from all models and selects the class with the highest average probability. It takes into account the confidence of each model’s prediction.
#
# In general, Soft Voting performs better than Hard Voting when models can provide reliable probability estimates, as it captures more information compared to simple majority voting.

# %% [markdown]
# ### Task 26: Implement Stacking Classifier with a meta-learner

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
stak_cls = StackingClassifier(
    estimators=[('dt',dt_cls),('knn',knn_cls),('svm',svm_cls)],
    final_estimator=lr,
    cv=5
)

# %%
stak_cls.fit(X_train_cls, y_train_cls)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('dt', DecisionTreeClassifier(random_state=42)),
#                                ('knn', KNeighborsClassifier()),
#                                ('svm', SVC(probability=True, random_state=42))],
#                    final_estimator=LogisticRegression())

# %% [markdown]
# ### Task 27: Implement Stacking Regressor for score prediction

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression

# %%
lin = LinearRegression()

# %%
# Base models for Voting Regression

dt_reg = DecisionTreeRegressor(random_state=42)
knn_reg = KNeighborsRegressor(n_neighbors=5)
svm_reg = SVR()

# %%
stak_reg = StackingRegressor(
    estimators=[('dt',dt_reg),('knn',knn_reg),('svm',svm_reg)],
    final_estimator=lin,
    cv=5
)

# %%
stak_reg.fit(X_train_reg, y_train_reg)
# Out:
# StackingRegressor(cv=5,
#                   estimators=[('dt', DecisionTreeRegressor(random_state=42)),
#                               ('knn', KNeighborsRegressor()), ('svm', SVR())],
#                   final_estimator=LinearRegression())

# %%
stak_pred_reg = stak_reg.predict(X_test_reg)

# %% [markdown]
# ## **Part F: Model Evaluation & Comparison**

# %% [markdown]
# ### Task 28: Evaluate classification models using:
# * Accuracy
# * Precision, Recall, F1-Score
# * ROC-AUC

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %%
def classification_from_dict(y_test, models_dict):
    
    results = []
    
    for name, y_pred in models_dict.items():
        data = {
            "Model": name,
            "Accuracy": accuracy_score(y_test, y_pred),
            "Precision": precision_score(y_test, y_pred),
            "Recall": recall_score(y_test, y_pred),
            "F1-Score": f1_score(y_test, y_pred)
        }
        results.append(data)
    
    return pd.DataFrame(results)

# %%
def roc_auc_for_models(models_dict, X_test, y_test):
    results = {}
    
    for name, model in models_dict.items():
        results[name] = get_roc_auc(model, X_test, y_test)
    
    return results

# %%
models_dict = {
    "Voting": vote_cls_soft,
    "Stacking":stak_cls,
    "Bagging": bag_cls,
    "GBM": gbm_cls,
    "LightGB": lgbm_cls,
    "AdaBoost": ada_cls,
    "XGBoost": xgb_cls 
}

# %%
pred_dict = {
    "Voting": (vote_pred_cls),
    "Stacking":(stak_pred_cls),
    "Bagging": (bag_pred_cls),
    "GBM":(gbm_pred_cls),
    "LightGB":(lgbm_pred_cls),
    "AdaBoost": (ada_pred_cls),
    "XGBoost": (xgb_pred_cls)
}

# %%
df_score = classification_from_dict(y_test_cls, pred_dict)
df_score
# Out:
#       Model  Accuracy  Precision    Recall  F1-Score
# 0    Voting  0.944231    0.95393  0.895674  0.923885
# 1  Stacking  1.000000    1.00000  1.000000  1.000000
# 2   Bagging  1.000000    1.00000  1.000000  1.000000
# 3       GBM  1.000000    1.00000  1.000000  1.000000
# 4   LightGB  1.000000    1.00000  1.000000  1.000000
# 5  AdaBoost  1.000000    1.00000  1.000000  1.000000
# 6   XGBoost  1.000000    1.00000  1.000000  1.000000

# %% [markdown]
# For the classification task, most models achieved perfect scores (100% accuracy, precision, recall, and F1-score). However, the Stacking Classifier is considered the best as it combines multiple models and provides more robust and generalized performance. The Voting model performed slightly lower compared to others.

# %%
df_roc = pd.DataFrame(roc_auc_for_models(models_dict,X_test_cls,y_test_cls),index=["Auc-Roc Score"])
df_roc.T
# Out:
#           Auc-Roc Score
# Voting         0.991025
# Stacking       1.000000
# Bagging        1.000000
# GBM            1.000000
# LightGB        1.000000
# AdaBoost       1.000000
# XGBoost        1.000000

# %% [markdown]
# ### Task 29: Evaluate regression models using:
# * MAE, RMSE
# * R² Score

# %%
def regression_from_dict(y_test, models_dict):
    
    results = []
    
    for name, y_pred in models_dict.items():
        data = {
            "Model": name,
            "MAE": mean_absolute_error(y_test, y_pred),
            "RMSE": np.sqrt(mean_squared_error(y_test, y_pred)),
            "R2 Score": r2_score(y_test, y_pred)
        }
        results.append(data)
    
    return pd.DataFrame(results)

# %%
models_reg = {
    "Bagging": (bag_pred_reg),
    "GBM":(gbm_pred_reg),
    "LightGB":(lgbm_pred_reg),
    "AdaBoost": (ada_pred_reg),
    "XGBoost": (xgb_pred_reg)
}

# %%
df_reg = regression_from_dict(y_test_reg, models_reg)
df_reg
# Out:
#       Model       MAE      RMSE  R2 Score
# 0   Bagging  0.007074  0.032232  0.999994
# 1       GBM  0.082592  0.113053  0.999932
# 2   LightGB  0.080154  0.261999  0.999633
# 3  AdaBoost  0.671307  0.848335  0.996148
# 4   XGBoost  0.071043  0.223395  0.999733

# %% [markdown]
# The regression models performed exceptionally well, with all models achieving very high R² scores close to 1. Among them, the Bagging Regressor delivered the best results with the lowest MAE and RMSE, indicating the most accurate and stable predictions.

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# ==========================
# Calculate Metrics
# ==========================

models = ["Bagging", "GBM", "LightGBM", "AdaBoost", "XGBoost"]

predictions = [
    bag_pred_reg,
    gbm_pred_reg,
    lgbm_pred_reg,
    ada_pred_reg,
    xgb_pred_reg
]

mae = []
rmse = []
r2_scores = []

for pred in predictions:
    mae.append(mean_absolute_error(y_test_reg, pred))
    rmse.append(np.sqrt(mean_squared_error(y_test_reg, pred)))
    r2_scores.append(r2_score(y_test_reg, pred))

# ==========================
# Create Figure
# ==========================

fig, axes = plt.subplots(1, 2, figsize=(18,7))

# --------------------------
# MAE vs RMSE
# --------------------------

x = np.arange(len(models))
width = 0.35

axes[0].bar(x-width/2, mae, width, color='royalblue', label='MAE')
axes[0].bar(x+width/2, rmse, width, color='tomato', label='RMSE')

axes[0].set_xticks(x)
axes[0].set_xticklabels(models, rotation=20)
axes[0].set_title("Model Error Comparison")
axes[0].set_xlabel("Models")
axes[0].set_ylabel("Error")
axes[0].legend()
axes[0].grid(axis='y', linestyle='--', alpha=0.5)

# --------------------------
# Residual Plot (Bagging)
# --------------------------

residuals = y_test_reg - bag_pred_reg

axes[1].scatter(
    bag_pred_reg,
    residuals,
    alpha=0.7,
    color='green'
)

axes[1].axhline(0, color='red', linestyle='--')

axes[1].set_title("Residual Plot (Bagging)")
axes[1].set_xlabel("Predicted Values")
axes[1].set_ylabel("Residuals")
axes[1].grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 30: Final Model Comparison & Conclusion

# %% [markdown]
# #### ✅ Best Regression Model:
# **Bagging Regressor**
#
# **Reason:**
# - Lowest MAE (0.007074)
# - Lowest RMSE (0.032232)
# - Highest R² Score (0.999994)
#
# 👉 This indicates extremely accurate predictions with minimal error.
#
# ---
#
#
# #### ✅ Best Classification Model:
# **Stacking Classifier (Recommended)**
#
# **Reason:**
# - Achieved perfect scores across all metrics
# - Combines multiple models → better generalization
# - More robust than individual models
#
# ---
#
# #### ⚠️ Important Observation
#
# Many models achieved **100% accuracy**, which may indicate:
# - Possible overfitting
# - Dataset might be too simple or small
#
# 👉 However, **Stacking is still preferred** because it combines strengths of multiple models.
#
# ---
#
# #### 🧠 Final Conclusion
#
# - **Best Regression Model:** Bagging Regressor
# - **Best Classification Model:** Stacking Classifier
#
# 👉 Ensemble methods performed exceptionally well in this project.
# 👉 Stacking provided the most reliable and generalized performance for classification tasks.
#
# ---

# %% [markdown]
# ## 📊 Part G: Final Analysis & Reporting

# %% [markdown]
# ### Task 31: Prepare Final Report Covering:

# %% [markdown]
# #### 🔹 1. Impact of Bagging vs Boosting
#
# ##### ✅ Bagging (Bootstrap Aggregating)
# - Reduces variance by training multiple models on random subsets of data
# - Models are trained independently
# - Works best for high-variance models like decision trees
#
# **Observation from Results:**
# - Bagging achieved the best performance in regression
# - Very low MAE and RMSE → highly stable predictions
#
# ---
#
# ##### ✅ Boosting (AdaBoost, GBM, XGBoost, LightGBM)
# - Reduces bias by training models sequentially
# - Each new model focuses on correcting previous errors
# - More powerful but can overfit
#
# **Observation from Results:**
# - Boosting models performed extremely well
# - However, slightly higher error compared to Bagging in regression
# - In classification, boosting models achieved perfect scores
#
# ---
#
# ###### 📌 Conclusion:
# - **Bagging → Better for stability and variance reduction**
# - **Boosting → Better for learning complex patterns**
#
# ---
#
# #### 🔹 2. Comparison of Tree-Based Boosting Algorithms
#
# ##### 🌳 AdaBoost
# - Simple boosting technique
# - Sensitive to noise
# - Lowest performance among boosting models in regression
#
# ---
#
# ##### 🌳 Gradient Boosting (GBM)
# - Improves performance by minimizing loss function
# - More stable than AdaBoost
#
# ---
#
# ##### 🌳 XGBoost
# - Optimized version of GBM
# - Faster and more efficient
# - Handles overfitting better using regularization
#
# ---
#
# ##### 🌳 LightGBM
# - Faster than XGBoost
# - Uses leaf-wise tree growth
# - Efficient for large datasets
#
# ---
#
# ##### 📊 Summary:
# - **XGBoost & LightGBM → Best performance**
# - **GBM → Balanced**
# - **AdaBoost → Least effective in this project**
#
# ---
#
# #### 🔹 3. Advantages of Voting and Stacking
#
# ##### ✅ Voting
# - Combines predictions using majority voting or averaging
# - Simple and effective
# - Improves overall model performance
#
# **Result Insight:**
# - Voting performed well but not as high as stacking
#
# ---
#
# ##### ✅ Stacking
# - Uses a meta-learner to combine predictions
# - Learns the best way to merge models
# - More powerful than voting
#
# **Result Insight:**
# - Achieved perfect accuracy (1.0)
# - Most robust and generalized model
#
# ---
#
# ##### 📌 Conclusion:
# - **Voting → Simple and fast**
# - **Stacking → Most powerful and accurate**
#
# ---
#
# #### 🔹 4. Final Model Recommendation for Deployment
#
# ##### 🏆 Recommended Models:
#
# ###### 🔹 Regression Task:
# 👉 **Bagging Regressor**
# - Lowest error
# - Highest R² score
# - Stable and reliable
#
# ---
#
# ###### 🔹 Classification Task:
# 👉 **Stacking Classifier**
# - Perfect performance across all metrics
# - Combines strengths of multiple models
# - Better generalization
#
# ---
#
# ##### ⚠️ Important Note:
# - Multiple models achieved 100% accuracy
# - This may indicate **overfitting or simple dataset**
# - Stacking is still preferred due to robustness
#
# ---
#
# #### 🔹 5. Business Interpretation
#
# - Accurate prediction of student performance helps:
#   - Identify weak students early
#   - Improve academic planning
#   - Optimize teaching strategies
#
# - Classification model helps:
#   - Predict completion status
#   - Take preventive actions
#
# ---
#
# #### 🔹 6. Final Conclusion
#
# - Ensemble methods significantly improved model performance
# - Bagging provided best regression results
# - Stacking provided best classification results
# - Models are suitable for deployment with further validation
#
# ---
#
# #### 🔹 7. Future Scope
#
# - Apply cross-validation for better reliability
# - Use larger and more complex datasets
# - Deploy on cloud platforms
# - Add explainability (SHAP, LIME)
# - Monitor model performance in real-time
#
# ---

# %% [markdown]
# ### Task 32: Final Conclusion

# %% [markdown]
# This project successfully demonstrated the application of ensemble learning techniques, including bagging, boosting, voting, and stacking, for both regression and classification tasks.
#
# The models were evaluated using appropriate performance metrics such as MAE, RMSE, R² Score for regression, and Accuracy, Precision, Recall, and F1-Score for classification. The results showed that ensemble methods significantly improved predictive performance compared to individual models.
#
# For the regression task, the **Bagging Regressor** achieved the best performance with the lowest error values and highest R² score, indicating highly accurate and stable predictions.
#
# For the classification task, the **Stacking Classifier** was selected as the final model due to its perfect performance across all evaluation metrics and its ability to combine multiple models effectively for better generalization.
#
# Although several models achieved 100% accuracy, this may indicate potential overfitting or a simple dataset. Therefore, further validation using cross-validation and real-world data is recommended.
#
# Overall, the project highlights the power of ensemble techniques in building robust and high-performing machine learning models. The final models are suitable for deployment and can assist in making data-driven decisions, such as predicting student performance and identifying completion status.
#
# The complete project, including source code, evaluation results, and deployment application, has been successfully prepared and submitted.
